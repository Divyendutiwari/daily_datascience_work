# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.8 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.9 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 14.1 MB/s eta 0:00:00
# ...
